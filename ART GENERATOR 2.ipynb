# %%
# !python --version
# Out:
# Python 3.6.9

# %%
# !nvidia-smi
# Out:
# Thu Nov 12 07:23:57 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.104      Driver Version: 410.104      CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0    31W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %% [markdown]
# INSTALL DEPENDENCIES

# %%
# !pip install scipy==1.3.3
# !pip install requests==2.22.0
# !pip install Pillow==6.2.1
# !pip install h5py==2.9.0
# !pip install imageio==2.9.0
# !pip install imageio-ffmpeg==0.4.2
# !pip install tqdm==4.49.0
# !pip install gdown
# !pip install tensorflow==1.12.0
# !pip install tensorflow-gpu==1.12.0
# Out:
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 20.3b1 is available.
# ...

# %% [markdown]
# DOWNLOAD DATASET

# %%
# !gdown --id 1uUvLopuy9DwLYZW5B8_basKQXYPbCS2J
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uUvLopuy9DwLYZW5B8_basKQXYPbCS2J
# To: /home/sheensantoscapadngan/processed_painting.zip
# 1.30GB [00:16, 78.0MB/s]

# %% [markdown]
# UNZIPPING DATASET

# %%
#if you manually uploaded your dataset to Colab, unzip it
zip_path = "/home/sheensantoscapadngan/processed_painting"
# !unzip {zip_path} -d /home/sheensantoscapadngan/
# Out:
# Archive:  /home/sheensantoscapadngan/processed_painting.zip
#    creating: /home/sheensantoscapadngan/processed_painting/
#   inflating: /home/sheensantoscapadngan/processed_painting/5387.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5388.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5389.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5390.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5391.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5392.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5393.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5394.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5395.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5396.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5397.jpg
#   inflating: /home/sheensantoscapadngan/processed_painting/5398.jpg
# ...

# %% [markdown]
# SETUP FOR STYLEGAN2 USE

# %%
import os
if os.path.isdir("/home/sheensantoscapadngan/colab-sg2-ada"):
    # %cd "/home/sheensantoscapadngan/colab-sg2-ada/stylegan2-ada"
else:
    #install script
    # %cd "/home/sheensantoscapadngan/"
    # !mkdir colab-sg2-ada
    # %cd colab-sg2-ada
    # !git clone https://github.com/dvschultz/stylegan2-ada
    # %cd stylegan2-ada
    # !mkdir downloads
    # !mkdir datasets
# Out:
# /home/sheensantoscapadngan/colab-sg2-ada/stylegan2-ada

# %%
#update this to the path to your image folder
dataset_path = "/home/sheensantoscapadngan/processed_painting"
#give your dataset a name
dataset_name = "painting"

#you don't need to edit anything here
# !python dataset_tool.py create_from_images ./datasets/{dataset_name} {dataset_path}
# Out:
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
 # !python train.py --help
# Out:
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
#this name must EXACTLY match the dataset name you used when creating the .tfrecords file
dataset_name = "painting"
#how often should the model generate samples and a .pkl file
snapshot_count = 2
#should the images be mirrored left to right?
mirrored = True
#should the images be mirrored top to bottom?
mirroredY = False
#metrics? 
metric_list = None
#augments
augs = "bg"

#
# this is the most important cell to update
#
# running it for the first time? set it to ffhq(+resolution)
# resuming? get the path to your latest .pkl file and use that

#resume_from = "/content/drive/My\ Drive/colab-sg2-ada2/stylegan2-ada/results/00008-dante1024-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000160.pkl"
resume_from = "/home/sheensantoscapadngan/colab-sg2-ada/stylegan2-ada/results/00010-painting-mirror-11gb-gpu-bg-resumecustom/network-snapshot-000064.pkl"
#resume_from = "ffhq512"

#don't edit this unless you know what you're doing :)
# !python train.py --outdir ./results --snap={snapshot_count} --cfg=11gb-gpu --data=./datasets/{dataset_name} --augpipe={augs} --mirror={mirrored} --mirrory={mirroredY} --metrics={metric_list} --resume={resume_from}
# Out:
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %% [markdown]
# <B> GENERATE IMAGES <B>

# %%
import os
os.environ["IMAGEIO_FFMPEG_EXE"] = "/usr/bin/ffmpeg"

# %%
final_model = "/home/sheensantoscapadngan/colab-sg2-ada/stylegan2-ada/results/00011-painting-mirror-11gb-gpu-bg-resumecustom/network-snapshot-000096.pkl"

# %%
# !python generate.py 'generate-images' --outdir=out --trunc=1 --seeds=5000-5010 --network={final_model} 
print("ITS DONE BRO")
# Out:
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sheensantoscapadngan/.pyenv/versions/3.6.9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...
